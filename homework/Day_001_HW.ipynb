# %%
作業一:
我所選擇的為判斷心血管疾病的數值, 根據取得的數值判斷是否某些跡象會誘發心血管的疾病
https://www.kaggle.com/ronitf/heart-disease-uci
1. 搜集身體血液中的多項數值, 藉由這些數值去判斷心臟疾病有可能是哪些因素誘發的, 或是哪些數值飆高導致心血管疾病的機率更高
2. 數據的提供者為一般的病患, 藉由檢測獲得病患身上的數據, 並將這些數據鍵入至資料庫中.
3. 基本上是
4. 針對這些病患所獲得的數據, 可以確定心血管疾病誘發的百分比有多高.

# %%
作業二:
1. 核心問題為“要如何提升業績”
2. 資料透過GPS可以收集車子跑的路徑, 或是開發一套App, 當使用者叫車, 搭車的時間距離或是搭車體驗都可以擷取數據
3. 視搜集的資料, 如果是價錢就為int, 搭車的起始或是結束時間搭配行駛的距離可以為物件形式或json.
4. 也許可以先建立某些預估的資料出來, 接著拿我們搜集到的資料與預估的資料做比對. 比對的過程中持續修正既有的預估資料, 當預估資料與獲得的資料落差逐漸變小, 也就代表離真正的數值越接近.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    """
    mse = MSE = sum(abs(y - yp) ** 2) / len(y)
    return mse

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 275.648
# The Mean absolute error is 13.603
